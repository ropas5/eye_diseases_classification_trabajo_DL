# %% [markdown]
# # Modelo VGG 5
#
# En este notebook probamos a ejecutar el modelo VGG sin el 3º bloque,
# partiendo de los pesos de `modelo_vgg_2`.
#
# Para reutilizar los pesos entre dos arquitecturas distintas sin que
# produzca un error, cargamos primero un modelo idéntico al de
# `modelo_vgg_2` e inicializamos sus pesos. Después creamos el nuevo
# modelo con la arquitectura reducida y transferimos únicamente los pesos
# de las capas cuyos nombres coinciden en ambos modelos.
#
# Este enfoque es una forma de **transfer learning interno**: en lugar de
# inicializar los pesos aleatoriamente, el modelo parte de pesos ya
# entrenados en el mismo problema, lo que en principio debería acelerar
# la convergencia y mejorar el resultado final.

# %%
# El siguiente codigo sirve para que el notebook funcione igual en colab o en local
# Si se ejecuta en la nube se cargue el repositorio, de esta forma se pueda acceder 
# a los diferentes archivos que necesite para su ejecución de forma automatica
import sys
import os

try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    repo_path = '/content/eye_diseases_classification_trabajo_DL'
    if not os.path.exists(repo_path):
        # !git clone https://github.com/ropas5/eye_diseases_classification_trabajo_DL.git
        sys.path.append('/content/eye_diseases_classification_trabajo_DL/notebooks')
    # from google.colab import userdata
    # userdata.get('kaggle')
    else:
        print("Repo ya existe, actualizando")
        # %cd /content/eye_diseases_classification_trabajo_DL/notebooks
        # !git pull 
        
    #Cargamos el kaggle.json
    import ipywidgets as widgets
    from IPython.display import display
    
    uploader = widgets.FileUpload(accept='.json')
    display(uploader)
else:
    print("Ejecución en local")
    uploader = None
# Out:
# Ejecución en local

# %% [markdown]
# ### Impotacion y preprocesado de datos

# %%
from importacion_preprocesado import descarga_y_carga_de_datos, preprocesamiento


tamany_img = (128,128) # tamaño reducido para colab, porque si no supera la ram
X, y = descarga_y_carga_de_datos(target_size=tamany_img, uploader= uploader)

X_train, X_val, X_test, y_train, y_val, y_test = preprocesamiento(X, y)
# Out:
# Dataset ya existe, solo se van a cargar las imágenes.
# X shape: (4217, 128, 128, 3) y shape: (4217,)

# %% [markdown]
# ### Modelo

# %%
# Importar el modelo
import sys
sys.path.append('../')

import importlib
import models.complejo_vgg_3
importlib.reload(models.complejo_vgg_3) # recargamos el cache para tener la ultima versión del modelo 
from models.complejo_vgg_3 import create_model

# Crear el modelo
model = create_model(input_shape=(128,128,3), num_classes=4, l_rate=0.0001, bloque = "block2_pool", IN_COLAB= IN_COLAB)

# %%
model.summary(expand_nested=True)
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional_4 (Functional)       │ (None, 32, 32, 128)    │       260,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ input_layer_3 (InputLayer) │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block1_conv1 (Conv2D)      │ (None, 128, 128, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block1_conv2 (Conv2D)      │ (None, 128, 128, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block1_pool (MaxPooling2D) │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block2_conv1 (Conv2D)      │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block2_conv2 (Conv2D)      │ (None, 64, 64, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block2_pool (MaxPooling2D) │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 458,564 (1.75 MB)
#  Trainable params: 458,564 (1.75 MB)
#  Non-trainable params: 0 (0.00 B)
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
hist = model.fit(X_train, y_train, validation_data= (X_val, y_val), epochs= 40)
# Out:
# Epoch 1/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 195s 2s/step - accuracy: 0.2479 - loss: 1.3863 - val_accuracy: 0.2547 - val_loss: 1.3862
# Epoch 2/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.2610 - loss: 1.3863 - val_accuracy: 0.2547 - val_loss: 1.3862
# Epoch 3/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 178s 2s/step - accuracy: 0.2610 - loss: 1.3863 - val_accuracy: 0.2547 - val_loss: 1.3862
# Epoch 4/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 197s 2s/step - accuracy: 0.2610 - loss: 1.3862 - val_accuracy: 0.2547 - val_loss: 1.3862
# Epoch 5/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.2610 - loss: 1.3862 - val_accuracy: 0.2547 - val_loss: 1.3862
# Epoch 6/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 187s 2s/step - accuracy: 0.2610 - loss: 1.3862 - val_accuracy: 0.2547 - val_loss: 1.3862
# Epoch 7/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 190s 2s/step - accuracy: 0.2610 - loss: 1.3862 - val_accuracy: 0.2547 - val_loss: 1.3861
# Epoch 8/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.2610 - loss: 1.3862 - val_accuracy: 0.2547 - val_loss: 1.3861
# Epoch 9/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.2610 - loss: 1.3861 - val_accuracy: 0.2547 - val_loss: 1.3860
# Epoch 10/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 0.2610 - loss: 1.3861 - val_accuracy: 0.2547 - val_loss: 1.3860
# Epoch 11/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.2610 - loss: 1.3861 - val_accuracy: 0.2547 - val_loss: 1.3860
# Epoch 12/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.2610 - loss: 1.3861 - val_accuracy: 0.2547 - val_loss: 1.3860
# Epoch 13/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 77s 964ms/step - accuracy: 0.2610 - loss: 1.3861 - val_accuracy: 0.2547 - val_loss: 1.3860
# Epoch 14/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 79s 982ms/step - accuracy: 0.2610 - loss: 1.3861 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 15/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 78s 981ms/step - accuracy: 0.2610 - loss: 1.3861 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 16/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.2610 - loss: 1.3860 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 17/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 167s 2s/step - accuracy: 0.2610 - loss: 1.3860 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 18/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 190s 2s/step - accuracy: 0.2610 - loss: 1.3860 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 19/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 194s 2s/step - accuracy: 0.2610 - loss: 1.3860 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 20/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 189s 2s/step - accuracy: 0.2610 - loss: 1.3860 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 21/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 174s 2s/step - accuracy: 0.2610 - loss: 1.3860 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 22/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 178s 2s/step - accuracy: 0.2610 - loss: 1.3860 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 23/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 191s 2s/step - accuracy: 0.2610 - loss: 1.3860 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 24/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 189s 2s/step - accuracy: 0.2610 - loss: 1.3860 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 25/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.2610 - loss: 1.3860 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 26/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.2610 - loss: 1.3860 - val_accuracy: 0.2547 - val_loss: 1.3858
# Epoch 27/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.2610 - loss: 1.3860 - val_accuracy: 0.2547 - val_loss: 1.3858
# Epoch 28/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.2610 - loss: 1.3859 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 29/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.2610 - loss: 1.3859 - val_accuracy: 0.2547 - val_loss: 1.3858
# Epoch 30/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.2610 - loss: 1.3859 - val_accuracy: 0.2547 - val_loss: 1.3858
# Epoch 31/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.2610 - loss: 1.3859 - val_accuracy: 0.2547 - val_loss: 1.3858
# Epoch 32/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.2610 - loss: 1.3859 - val_accuracy: 0.2547 - val_loss: 1.3858
# Epoch 33/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.2610 - loss: 1.3859 - val_accuracy: 0.2547 - val_loss: 1.3858
# Epoch 34/40
# 62/80 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.2656 - loss: 1.3853

# %% [markdown]
# ### Resultados

# %%
import matplotlib.pyplot as plt
import numpy as np


# número de épocas para el zoom
zoom_epochs = 20

loss = hist.history['loss']
val_loss = hist.history['val_loss']
acc = hist.history["accuracy"]
val_acc = hist.history["val_accuracy"]

epochs = range(1, len(loss) + 1)

fig, ax = plt.subplots(2, 2, figsize=(13,10))
ax  = ax.flatten()
fig.suptitle('Training History', fontsize=15, fontweight='bold')

# Visualizacion evolucion loss durante el entrenamiento
ax[0].plot( loss, label='Train loss', color = "blue")
ax[0].plot( val_loss, label='Val loss', color= "yellow")
ax[0].set_title('Training loss evolution')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].grid(True, alpha = 0.4)
ax[0].legend()

# Zoom últimas épocas
ax[1].plot(epochs[-zoom_epochs:], loss[-zoom_epochs:], label='Train loss', color = "blue")
ax[1].plot(epochs[-zoom_epochs:], val_loss[-zoom_epochs:], label='Val loss', color= "yellow")
ax[1].set_title(f'Zoom últimas {zoom_epochs} epocas')
ax[1].set_xlabel('Epoch')
ax[1].grid(True, alpha = 0.4)
ax[1].legend()

# Visualizacion de accuracy durante el entrenamiento
ax[2].plot( acc, label='Train accuracy', color = "blue")
ax[2].plot( val_acc, label='Val accuracy', color= "yellow")
ax[2].grid(True, alpha = 0.4)
ax[2].set_ylim(0,1)
ax[2].set_title('Training accuracy evolution')
ax[2].set_ylabel('accuracy')
ax[2].legend()

# Zoom últimas épocas
ax[3].plot(epochs[-zoom_epochs:], acc[-zoom_epochs:], label='Train accuracy', color = "blue")
ax[3].plot(epochs[-zoom_epochs:], val_acc[-zoom_epochs:], label='Val accuracy', color= "yellow")
ax[3].set_title(f'Zoom últimas {zoom_epochs} epocas')
ax[3].grid(True, alpha = 0.4)
ax[3].legend()

plt.tight_layout()
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, f1_score

datasets = {
    "Train": (X_train, y_train),
    "Val": (X_val, y_val),
    "Test": (X_test, y_test)
}

def evaluate(model, X, y):
    #Convertir a enteros
    y_true = np.argmax(y, axis=1)

    y_pred_probs = model.predict(X)
    y_pred = np.argmax(y_pred_probs, axis=1)

    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average="weighted")
    return acc, f1


def crear_df_metricas(model, datasets):
    results = {}
    for split_name, (X, y) in datasets.items():
        acc, f1 = evaluate(model, X, y)
        results[split_name] = [acc, f1]
    
    df = pd.DataFrame(results, index=["Accuracy", "F1"])
    return df
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
df = crear_df_metricas(model, datasets)
print(df.round(3))
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 16s 195ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step
#           Train    Val   Test
# Accuracy  0.261  0.255  0.236
# F1        0.108  0.103  0.090
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
def plot_barra(metrica, titulo, color):

    plt.figure(figsize=(6,4))
    bars = plt.bar(metrica.index, metrica.values, color=color)
    plt.bar_label(bars)
    plt.title(f"{titulo}: Train vs Validation vs Test")
    plt.ylabel(titulo)
    plt.ylim(0,1)
    plt.grid(axis='y', linestyle='--')
    plt.show()


def plots_metricas(df):
    #Extraemos la fila
    accuracy = df.loc["Accuracy"]
    f1 = df.loc["F1"]

    #Grafico de Accuracy
    plot_barra(accuracy, titulo = "Accuracy", color="blue")

    #Grafico de 
    plot_barra(f1, titulo ="F1", color = "red")
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
plots_metricas(df)
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_true = np.argmax(y_test, axis=1)
y_pred = np.argmax(model.predict(X_test), axis=1)

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm,  
                    display_labels= ["cataract", "diabetic_retinopathy", "glaucoma", "normal"]
                    ).plot(cmap="Blues", xticks_rotation= 45.0)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
from sklearn.metrics import precision_recall_fscore_support

def per_class_table(model, datasets):
    # class_names: lista con nombres de las clases en el orden de los índices (opcional)
    class_names = ["cataract", "diabetic_retinopathy", "glaucoma", "normal"]  

    splits = list(datasets.keys())
    # identificamos número de clases desde los datos si no dan nombres
    sample_X, sample_y = next(iter(datasets.values()))
    n_classes = np.argmax(sample_y, axis=1).max() + 1

    # DataFrame con index = clases y columnas por split/metric
    cols = []
    for s in splits:
        cols += [f"{s}_Accuracy", f"{s}_F1"]
    df = pd.DataFrame(index=class_names, columns=cols, dtype=float)

    for split in splits:
        X, y = datasets[split]
        y_true = np.argmax(y, axis=1)
        y_pred = np.argmax(model.predict(X), axis=1)

        # precision, recall, f1 por clase
        precision, recall, f1, support = precision_recall_fscore_support(
            y_true, y_pred, labels=np.arange(n_classes), zero_division=0
        )
        # Aquí definimos "Accuracy" por clase como recall (TP / nº verdaderos de la clase)
        for i, cls in enumerate(class_names):
            df.loc[cls, f"{split}_Accuracy"] = recall[i]
            df.loc[cls, f"{split}_F1"] = f1[i]

    return df
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
df_per_class = per_class_table(model, datasets)
print(df_per_class.round(3))
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 17s 209ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step
#                       Train_Accuracy  Train_F1  Val_Accuracy  Val_F1  \
# cataract                         0.0     0.000           0.0   0.000
# diabetic_retinopathy             0.0     0.000           0.0   0.000
# glaucoma                         0.0     0.000           0.0   0.000
# normal                           1.0     0.414           1.0   0.406
#
#                       Test_Accuracy  Test_F1
# cataract                        0.0    0.000
# diabetic_retinopathy            0.0    0.000
# glaucoma                        0.0    0.000
# normal                          1.0    0.382
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
MODEL_NAME = "modelo_vgg_5"          
EPOCHS     = len(hist.epoch)
results = {
    "modelo":         MODEL_NAME,
    "epochs":         EPOCHS,
    "Train Accuracy": df.loc["Accuracy", "Train"],
    "Val Accuracy":   df.loc["Accuracy", "Val"],
    "Test Accuracy":  df.loc["Accuracy", "Test"],
    "Train F1":       df.loc["F1", "Train"],
    "Val F1":         df.loc["F1", "Val"],
    "Test F1":        df.loc["F1", "Test"],

}

# Ruta del CSV
CSV_PATH = "../data/processed/model_results.csv"

if os.path.exists(CSV_PATH):
    df = pd.read_csv(CSV_PATH)
    df = pd.concat([df, pd.DataFrame([results])], ignore_index=True)
else:
    df = pd.DataFrame([results])

df.to_csv(CSV_PATH, index=False)
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
df
# Out:
#                    modelo  epochs  Train Accuracy  Val Accuracy  \
# 0         modelo_4_simple     160        0.879794      0.866114
# 1                modelo_3     140        0.469751      0.483412
# 2         modelo_2_simple     150        0.567813      0.555687
# 3         modelo_3_simple     160        0.762357      0.748815
# 4         modelo_5_simple     160        0.741795      0.736967
# 5         modelo_2_simple     150        0.736259      0.726303
# 6         modelo_3_simple     160        0.746540      0.755924
# 7         modelo_2_simple     200        0.811388      0.806872
# 8         modelo_2_simple     200        0.855674      0.832938
# 9         modelo_7_simple     100        0.771451      0.750000
# 10  modelo_4_simple_0.001     200        0.791222      0.771327
# 11           modelo_vgg_2      40        0.260973      0.254739
# 12           modelo_vgg_5       5        0.260973      0.254739
#
#     Test Accuracy  Train F1    Val F1   Test F1
# 0        0.859005  0.877048  0.859835  0.854445
# 1        0.462085  0.467340  0.480129  0.462396
# 2        0.584123  0.545662  0.539349  0.566327
# 3        0.718009  0.744839  0.734888  0.698080
# 4        0.718009  0.725975  0.723727  0.703048
# 5        0.710900  0.712005  0.699472  0.685075
# 6        0.740521  0.737455  0.747230  0.730042
# 7        0.795024  0.801620  0.792162  0.784455
# 8        0.840047  0.850542  0.824181  0.835019
# 9        0.740521  0.758887  0.733037  0.729129
# 10       0.746445  0.788109  0.767324  0.743371
# 11       0.235782  0.108023  0.103435  0.089972
# 12       0.235782  0.108023  0.103435  0.089972
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.
