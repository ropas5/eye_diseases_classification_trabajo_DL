# %% [markdown]
# # Modelo Simple 3

# %% [markdown]
# En este modelo añadimos una 3 capa convolucioal, con las mismas dimensiónes de las otras 2, tamaño de filtro 16 y tamaño de kernel 3.

# %%
# El siguiente codigo sirve para que el notebook funcione igual en colab o en local
# Si se ejecuta en la nube se cargue el repositorio, de esta forma se pueda acceder 
# a los diferentes archivos que necesite para su ejecución de forma automatica
import sys
import os

try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    repo_path = '/content/eye_diseases_classification_trabajo_DL'
    if not os.path.exists(repo_path):
        # !git clone https://github.com/ropas5/eye_diseases_classification_trabajo_DL.git
        sys.path.append('/content/eye_diseases_classification_trabajo_DL/notebooks')
    # from google.colab import userdata
    # userdata.get('kaggle')
    else:
        print("Repo ya existe, actualizando")
        # %cd /content/eye_diseases_classification_trabajo_DL/notebooks
        # !git pull 
        
    #Cargamos el kaggle.json
    import ipywidgets as widgets
    from IPython.display import display
    
    uploader = widgets.FileUpload(accept='.json')
    display(uploader)
else:
    print("Ejecución en local")
    uploader = None
# Out:
# Ejecución en local

# %% [markdown]
# ### Impotacion y preprocesado de datos

# %%
from importacion_preprocesado import descarga_y_carga_de_datos, preprocesamiento


tamany_img = (128,128) # tamaño reducido para colab, porque si no supera la ram
X, y = descarga_y_carga_de_datos(target_size=tamany_img, uploader=uploader)

X_train, X_val, X_test, y_train, y_val, y_test = preprocesamiento(X, y)
# Out:
# Dataset ya existe, solo se van a cargar las imágenes.
# X shape: (4217, 128, 128, 3) y shape: (4217,)

# %% [markdown]
# ### Modelo

# %%
# Importar el modelo
import sys
sys.path.append('../')

import importlib
import models.simple_3_cnn
importlib.reload(models.simple_3_cnn) # recargamos el cache para tener la ultima versión del modelo 
from models.simple_3_cnn import create_model

# Crear el modelo
model = create_model(input_shape=(128,128,3), num_classes=4, l_rate=0.01)
# Out:
# c:\Users\roger\miniconda3\envs\dl\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_13 (Conv2D)              │ (None, 126, 126, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 124, 124, 16)   │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 122, 122, 16)   │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_5      │ (None, 16)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 4)              │            68 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,156 (20.14 KB)
#  Trainable params: 5,156 (20.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Entrenamiento

# %%
hist = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=160
)
# Out:
# Epoch 1/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 45s 267ms/step - accuracy: 0.3076 - loss: 1.3609 - val_accuracy: 0.4017 - val_loss: 1.3157
# Epoch 2/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 38s 231ms/step - accuracy: 0.3772 - loss: 1.2770 - val_accuracy: 0.3697 - val_loss: 1.2791
# Epoch 3/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 225ms/step - accuracy: 0.3693 - loss: 1.2583 - val_accuracy: 0.4277 - val_loss: 1.2506
# Epoch 4/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 16s 194ms/step - accuracy: 0.4227 - loss: 1.2350 - val_accuracy: 0.4182 - val_loss: 1.2138
# Epoch 5/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 223ms/step - accuracy: 0.4199 - loss: 1.2318 - val_accuracy: 0.4360 - val_loss: 1.2043
# Epoch 6/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 17s 215ms/step - accuracy: 0.4409 - loss: 1.2146 - val_accuracy: 0.4609 - val_loss: 1.2226
# Epoch 7/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 16s 197ms/step - accuracy: 0.4231 - loss: 1.2321 - val_accuracy: 0.4775 - val_loss: 1.2240
# Epoch 8/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 17s 215ms/step - accuracy: 0.4516 - loss: 1.2081 - val_accuracy: 0.4680 - val_loss: 1.2028
# Epoch 9/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 19s 234ms/step - accuracy: 0.4630 - loss: 1.2089 - val_accuracy: 0.4538 - val_loss: 1.2085
# Epoch 10/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 17s 184ms/step - accuracy: 0.4492 - loss: 1.2093 - val_accuracy: 0.3851 - val_loss: 1.2327
# Epoch 11/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - accuracy: 0.4401 - loss: 1.2242 - val_accuracy: 0.4645 - val_loss: 1.2110
# Epoch 12/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 19s 228ms/step - accuracy: 0.4614 - loss: 1.2143 - val_accuracy: 0.4775 - val_loss: 1.1894
# Epoch 13/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 17s 212ms/step - accuracy: 0.4630 - loss: 1.2027 - val_accuracy: 0.4858 - val_loss: 1.1819
# Epoch 14/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 15s 186ms/step - accuracy: 0.4626 - loss: 1.2141 - val_accuracy: 0.4775 - val_loss: 1.1956
# Epoch 15/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 163ms/step - accuracy: 0.4725 - loss: 1.1995 - val_accuracy: 0.4680 - val_loss: 1.2121
# Epoch 16/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.4788 - loss: 1.1976 - val_accuracy: 0.5024 - val_loss: 1.1828
# Epoch 17/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.4844 - loss: 1.1732 - val_accuracy: 0.4941 - val_loss: 1.1471
# Epoch 18/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 15s 179ms/step - accuracy: 0.5212 - loss: 1.0942 - val_accuracy: 0.5284 - val_loss: 1.0829
# Epoch 19/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.5722 - loss: 1.0003 - val_accuracy: 0.6055 - val_loss: 0.9439
# Epoch 20/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 163ms/step - accuracy: 0.6232 - loss: 0.8776 - val_accuracy: 0.6754 - val_loss: 0.8309
# Epoch 21/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 14s 176ms/step - accuracy: 0.6489 - loss: 0.8408 - val_accuracy: 0.5047 - val_loss: 1.0575
# Epoch 22/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 15s 191ms/step - accuracy: 0.6358 - loss: 0.8346 - val_accuracy: 0.6967 - val_loss: 0.7661
# Epoch 23/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.6714 - loss: 0.7882 - val_accuracy: 0.7014 - val_loss: 0.7426
# Epoch 24/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.6785 - loss: 0.7750 - val_accuracy: 0.6931 - val_loss: 0.7700
# Epoch 25/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - accuracy: 0.6615 - loss: 0.7785 - val_accuracy: 0.7145 - val_loss: 0.7590
# Epoch 26/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - accuracy: 0.6758 - loss: 0.7639 - val_accuracy: 0.5806 - val_loss: 0.9157
# Epoch 27/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 14s 170ms/step - accuracy: 0.6738 - loss: 0.7624 - val_accuracy: 0.6528 - val_loss: 0.8396
# Epoch 28/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 130ms/step - accuracy: 0.6675 - loss: 0.7703 - val_accuracy: 0.7014 - val_loss: 0.7229
# Epoch 29/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.6900 - loss: 0.7338 - val_accuracy: 0.6718 - val_loss: 0.7926
# Epoch 30/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.6667 - loss: 0.7584 - val_accuracy: 0.5498 - val_loss: 0.9861
# Epoch 31/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.6501 - loss: 0.8420 - val_accuracy: 0.7192 - val_loss: 0.6881
# Epoch 32/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 142ms/step - accuracy: 0.6967 - loss: 0.7071 - val_accuracy: 0.6848 - val_loss: 0.7095
# Epoch 33/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.6920 - loss: 0.7173 - val_accuracy: 0.6623 - val_loss: 0.8108
# Epoch 34/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 0.6959 - loss: 0.7347 - val_accuracy: 0.6706 - val_loss: 0.7391
# Epoch 35/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.6904 - loss: 0.7024 - val_accuracy: 0.7464 - val_loss: 0.6621
# Epoch 36/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.7026 - loss: 0.6919 - val_accuracy: 0.6114 - val_loss: 0.8957
# Epoch 37/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.6319 - loss: 0.9630 - val_accuracy: 0.7227 - val_loss: 0.7027
# Epoch 38/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.6983 - loss: 0.7017 - val_accuracy: 0.7441 - val_loss: 0.6585
# Epoch 39/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 0.7094 - loss: 0.6857 - val_accuracy: 0.7393 - val_loss: 0.6534
# Epoch 40/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - accuracy: 0.7026 - loss: 0.6825 - val_accuracy: 0.7073 - val_loss: 0.6688
# Epoch 41/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.6924 - loss: 0.7057 - val_accuracy: 0.7322 - val_loss: 0.6800
# Epoch 42/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 137ms/step - accuracy: 0.6991 - loss: 0.6946 - val_accuracy: 0.7275 - val_loss: 0.6384
# Epoch 43/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 139ms/step - accuracy: 0.7046 - loss: 0.6758 - val_accuracy: 0.7002 - val_loss: 0.6803
# Epoch 44/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.6979 - loss: 0.6911 - val_accuracy: 0.7346 - val_loss: 0.6623
# Epoch 45/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.7003 - loss: 0.6683 - val_accuracy: 0.7512 - val_loss: 0.6365
# Epoch 46/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.7106 - loss: 0.6637 - val_accuracy: 0.7370 - val_loss: 0.6258
# Epoch 47/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - accuracy: 0.7086 - loss: 0.6661 - val_accuracy: 0.6825 - val_loss: 0.7261
# Epoch 48/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 21s 149ms/step - accuracy: 0.6845 - loss: 0.7092 - val_accuracy: 0.7524 - val_loss: 0.6469
# Epoch 49/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.6995 - loss: 0.6816 - val_accuracy: 0.7133 - val_loss: 0.6962
# Epoch 50/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.6789 - loss: 0.7298 - val_accuracy: 0.7559 - val_loss: 0.6296
# Epoch 51/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.7121 - loss: 0.6557 - val_accuracy: 0.7500 - val_loss: 0.6233
# Epoch 52/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.7050 - loss: 0.6723 - val_accuracy: 0.7346 - val_loss: 0.6470
# Epoch 53/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.7149 - loss: 0.6542 - val_accuracy: 0.6955 - val_loss: 0.6741
# Epoch 54/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 0.6971 - loss: 0.6743 - val_accuracy: 0.6979 - val_loss: 0.6782
# Epoch 55/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.7165 - loss: 0.6596 - val_accuracy: 0.7287 - val_loss: 0.6264
# Epoch 56/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.7185 - loss: 0.6532 - val_accuracy: 0.7453 - val_loss: 0.6111
# Epoch 57/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.7078 - loss: 0.6529 - val_accuracy: 0.7476 - val_loss: 0.6166
# Epoch 58/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 160ms/step - accuracy: 0.7066 - loss: 0.6604 - val_accuracy: 0.6682 - val_loss: 0.6835
# Epoch 59/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - accuracy: 0.7007 - loss: 0.6675 - val_accuracy: 0.7583 - val_loss: 0.6112
# Epoch 60/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.7173 - loss: 0.6548 - val_accuracy: 0.7547 - val_loss: 0.6026
# Epoch 61/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.7121 - loss: 0.6472 - val_accuracy: 0.7500 - val_loss: 0.6116
# Epoch 62/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - accuracy: 0.7153 - loss: 0.6499 - val_accuracy: 0.7441 - val_loss: 0.6177
# Epoch 63/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.7141 - loss: 0.6375 - val_accuracy: 0.7500 - val_loss: 0.6013
# Epoch 64/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.7121 - loss: 0.6362 - val_accuracy: 0.7500 - val_loss: 0.6318
# Epoch 65/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.7082 - loss: 0.6598 - val_accuracy: 0.7050 - val_loss: 0.6936
# Epoch 66/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 0.7038 - loss: 0.6647 - val_accuracy: 0.7476 - val_loss: 0.6115
# Epoch 67/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - accuracy: 0.7117 - loss: 0.6533 - val_accuracy: 0.7453 - val_loss: 0.6179
# Epoch 68/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.7189 - loss: 0.6405 - val_accuracy: 0.7417 - val_loss: 0.6315
# Epoch 69/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.7197 - loss: 0.6388 - val_accuracy: 0.7701 - val_loss: 0.5891
# Epoch 70/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.7173 - loss: 0.6268 - val_accuracy: 0.7654 - val_loss: 0.5961
# Epoch 71/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.7220 - loss: 0.6341 - val_accuracy: 0.7453 - val_loss: 0.5911
# Epoch 72/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.7224 - loss: 0.6449 - val_accuracy: 0.7642 - val_loss: 0.5836
# Epoch 73/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.7268 - loss: 0.6123 - val_accuracy: 0.7382 - val_loss: 0.6068
# Epoch 74/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 155ms/step - accuracy: 0.7208 - loss: 0.6341 - val_accuracy: 0.7476 - val_loss: 0.6102
# Epoch 75/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.7224 - loss: 0.6165 - val_accuracy: 0.7559 - val_loss: 0.5828
# Epoch 76/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.7264 - loss: 0.6192 - val_accuracy: 0.7500 - val_loss: 0.5823
# Epoch 77/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.7311 - loss: 0.6071 - val_accuracy: 0.7405 - val_loss: 0.6209
# Epoch 78/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.6955 - loss: 0.6720 - val_accuracy: 0.7618 - val_loss: 0.5806
# Epoch 79/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - accuracy: 0.7236 - loss: 0.6177 - val_accuracy: 0.7500 - val_loss: 0.5984
# Epoch 80/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.7268 - loss: 0.6178 - val_accuracy: 0.7536 - val_loss: 0.5917
# Epoch 81/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - accuracy: 0.7260 - loss: 0.6173 - val_accuracy: 0.7524 - val_loss: 0.5991
# Epoch 82/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.7232 - loss: 0.6119 - val_accuracy: 0.7559 - val_loss: 0.6109
# Epoch 83/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 0.7204 - loss: 0.6441 - val_accuracy: 0.7547 - val_loss: 0.5923
# Epoch 84/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 155ms/step - accuracy: 0.7228 - loss: 0.6136 - val_accuracy: 0.7441 - val_loss: 0.5984
# Epoch 85/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.7248 - loss: 0.6228 - val_accuracy: 0.7607 - val_loss: 0.5696
# Epoch 86/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.7343 - loss: 0.6047 - val_accuracy: 0.7382 - val_loss: 0.6081
# Epoch 87/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.7406 - loss: 0.6105 - val_accuracy: 0.7713 - val_loss: 0.5836
# Epoch 88/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - accuracy: 0.7327 - loss: 0.6014 - val_accuracy: 0.7547 - val_loss: 0.5741
# Epoch 89/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.7327 - loss: 0.5983 - val_accuracy: 0.7346 - val_loss: 0.6019
# Epoch 90/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - accuracy: 0.7390 - loss: 0.5952 - val_accuracy: 0.7346 - val_loss: 0.6080
# Epoch 91/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - accuracy: 0.7363 - loss: 0.5940 - val_accuracy: 0.7630 - val_loss: 0.5612
# Epoch 92/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 154ms/step - accuracy: 0.7303 - loss: 0.5969 - val_accuracy: 0.6919 - val_loss: 0.6389
# Epoch 93/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.7181 - loss: 0.6208 - val_accuracy: 0.7607 - val_loss: 0.5666
# Epoch 94/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - accuracy: 0.7386 - loss: 0.5869 - val_accuracy: 0.7618 - val_loss: 0.5732
# Epoch 95/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 163ms/step - accuracy: 0.7402 - loss: 0.5905 - val_accuracy: 0.7512 - val_loss: 0.5765
# Epoch 96/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.7422 - loss: 0.6093 - val_accuracy: 0.7654 - val_loss: 0.5638
# Epoch 97/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.7434 - loss: 0.5869 - val_accuracy: 0.7618 - val_loss: 0.5691
# Epoch 98/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - accuracy: 0.7410 - loss: 0.5873 - val_accuracy: 0.7405 - val_loss: 0.5780
# Epoch 99/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.7327 - loss: 0.5916 - val_accuracy: 0.7559 - val_loss: 0.5796
# Epoch 100/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 0.7386 - loss: 0.5958 - val_accuracy: 0.7583 - val_loss: 0.5732
# Epoch 101/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 156ms/step - accuracy: 0.7398 - loss: 0.5846 - val_accuracy: 0.7690 - val_loss: 0.5765
# Epoch 102/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.7339 - loss: 0.5906 - val_accuracy: 0.7453 - val_loss: 0.5976
# Epoch 103/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 0.7382 - loss: 0.5948 - val_accuracy: 0.7630 - val_loss: 0.5705
# Epoch 104/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 0.7410 - loss: 0.5908 - val_accuracy: 0.7287 - val_loss: 0.6195
# Epoch 105/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.7335 - loss: 0.6030 - val_accuracy: 0.7168 - val_loss: 0.6494
# Epoch 106/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - accuracy: 0.7284 - loss: 0.5996 - val_accuracy: 0.7642 - val_loss: 0.5619
# Epoch 107/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.7422 - loss: 0.5876 - val_accuracy: 0.7654 - val_loss: 0.5630
# Epoch 108/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step - accuracy: 0.7359 - loss: 0.5867 - val_accuracy: 0.7382 - val_loss: 0.6101
# Epoch 109/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 0.7287 - loss: 0.6101 - val_accuracy: 0.7630 - val_loss: 0.5618
# Epoch 110/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 111ms/step - accuracy: 0.7450 - loss: 0.5755 - val_accuracy: 0.7524 - val_loss: 0.5653
# Epoch 111/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.7394 - loss: 0.5843 - val_accuracy: 0.7429 - val_loss: 0.6043
# Epoch 112/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.7418 - loss: 0.5851 - val_accuracy: 0.7500 - val_loss: 0.5751
# Epoch 113/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.7446 - loss: 0.5914 - val_accuracy: 0.7429 - val_loss: 0.5840
# Epoch 114/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.7461 - loss: 0.5841 - val_accuracy: 0.7618 - val_loss: 0.5699
# Epoch 115/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.7446 - loss: 0.5865 - val_accuracy: 0.6967 - val_loss: 0.6442
# Epoch 116/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.7149 - loss: 0.6409 - val_accuracy: 0.7618 - val_loss: 0.5687
# Epoch 117/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.7473 - loss: 0.5805 - val_accuracy: 0.7654 - val_loss: 0.5561
# Epoch 118/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.7485 - loss: 0.5738 - val_accuracy: 0.7476 - val_loss: 0.5732
# Epoch 119/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 92ms/step - accuracy: 0.7323 - loss: 0.5847 - val_accuracy: 0.7476 - val_loss: 0.5892
# Epoch 120/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 92ms/step - accuracy: 0.7457 - loss: 0.5920 - val_accuracy: 0.7583 - val_loss: 0.5674
# Epoch 121/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.7422 - loss: 0.5754 - val_accuracy: 0.7453 - val_loss: 0.5739
# Epoch 122/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.7505 - loss: 0.5706 - val_accuracy: 0.7536 - val_loss: 0.5767
# Epoch 123/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.7394 - loss: 0.5911 - val_accuracy: 0.7559 - val_loss: 0.5949
# Epoch 124/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.7371 - loss: 0.5794 - val_accuracy: 0.7097 - val_loss: 0.6263
# Epoch 125/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.7541 - loss: 0.5687 - val_accuracy: 0.7417 - val_loss: 0.6060
# Epoch 126/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.7465 - loss: 0.6052 - val_accuracy: 0.6291 - val_loss: 0.8892
# Epoch 127/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 139ms/step - accuracy: 0.6627 - loss: 0.8784 - val_accuracy: 0.7630 - val_loss: 0.5987
# Epoch 128/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.7335 - loss: 0.5953 - val_accuracy: 0.7559 - val_loss: 0.5813
# Epoch 129/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.7347 - loss: 0.5907 - val_accuracy: 0.7476 - val_loss: 0.5979
# Epoch 130/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.7394 - loss: 0.5922 - val_accuracy: 0.7630 - val_loss: 0.5797
# Epoch 131/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.7299 - loss: 0.5959 - val_accuracy: 0.7322 - val_loss: 0.5919
# Epoch 132/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.7351 - loss: 0.5897 - val_accuracy: 0.7690 - val_loss: 0.5693
# Epoch 133/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.7378 - loss: 0.5950 - val_accuracy: 0.7690 - val_loss: 0.5690
# Epoch 134/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.7406 - loss: 0.5850 - val_accuracy: 0.7441 - val_loss: 0.5779
# Epoch 135/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.7351 - loss: 0.5922 - val_accuracy: 0.7500 - val_loss: 0.5951
# Epoch 136/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.7390 - loss: 0.5871 - val_accuracy: 0.7453 - val_loss: 0.5793
# Epoch 137/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.7398 - loss: 0.5807 - val_accuracy: 0.7607 - val_loss: 0.5733
# Epoch 138/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 0.7378 - loss: 0.5871 - val_accuracy: 0.7405 - val_loss: 0.5914
# Epoch 139/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.7477 - loss: 0.5840 - val_accuracy: 0.7536 - val_loss: 0.5887
# Epoch 140/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 0.7351 - loss: 0.5911 - val_accuracy: 0.7571 - val_loss: 0.5768
# Epoch 141/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - accuracy: 0.7426 - loss: 0.5922 - val_accuracy: 0.7464 - val_loss: 0.5818
# Epoch 142/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 155ms/step - accuracy: 0.7418 - loss: 0.5795 - val_accuracy: 0.7512 - val_loss: 0.5772
# Epoch 143/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.7291 - loss: 0.6018 - val_accuracy: 0.7559 - val_loss: 0.5806
# Epoch 144/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.7414 - loss: 0.5848 - val_accuracy: 0.7500 - val_loss: 0.5867
# Epoch 145/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 0.7359 - loss: 0.5840 - val_accuracy: 0.7417 - val_loss: 0.5958
# Epoch 146/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 160ms/step - accuracy: 0.7418 - loss: 0.5833 - val_accuracy: 0.7263 - val_loss: 0.6038
# Epoch 147/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - accuracy: 0.7473 - loss: 0.5745 - val_accuracy: 0.7500 - val_loss: 0.5688
# Epoch 148/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 142ms/step - accuracy: 0.7414 - loss: 0.5868 - val_accuracy: 0.7417 - val_loss: 0.6056
# Epoch 149/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.7371 - loss: 0.5864 - val_accuracy: 0.7524 - val_loss: 0.5762
# Epoch 150/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.7473 - loss: 0.5799 - val_accuracy: 0.7500 - val_loss: 0.5814
# Epoch 151/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.7418 - loss: 0.5724 - val_accuracy: 0.7678 - val_loss: 0.5762
# Epoch 152/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.7438 - loss: 0.5778 - val_accuracy: 0.7536 - val_loss: 0.5779
# Epoch 153/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.7398 - loss: 0.5872 - val_accuracy: 0.7393 - val_loss: 0.5740
# Epoch 154/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.7489 - loss: 0.5765 - val_accuracy: 0.7571 - val_loss: 0.5801
# Epoch 155/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 22s 158ms/step - accuracy: 0.7477 - loss: 0.5894 - val_accuracy: 0.7275 - val_loss: 0.6105
# Epoch 156/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.7446 - loss: 0.5770 - val_accuracy: 0.7547 - val_loss: 0.5844
# Epoch 157/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.7398 - loss: 0.5853 - val_accuracy: 0.7097 - val_loss: 0.6320
# Epoch 158/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.7497 - loss: 0.5750 - val_accuracy: 0.7512 - val_loss: 0.5979
# Epoch 159/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.7398 - loss: 0.5756 - val_accuracy: 0.7488 - val_loss: 0.5885
# Epoch 160/160
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 0.7295 - loss: 0.5967 - val_accuracy: 0.7559 - val_loss: 0.5791

# %% [markdown]
# ### Resultados

# %%
import matplotlib.pyplot as plt
import numpy as np

# número de épocas para el zoom
zoom_epochs = 20

loss = hist.history['loss']
val_loss = hist.history['val_loss']
acc = hist.history["accuracy"]
val_acc = hist.history["val_accuracy"]

epochs = range(1, len(loss) + 1)

fig, ax = plt.subplots(2, 2, figsize=(13,10))
ax  = ax.flatten()
fig.suptitle('Training History', fontsize=15, fontweight='bold')

# Visualizacion evolucion loss durante el entrenamiento
ax[0].plot( loss, label='Train loss', color = "blue")
ax[0].plot( val_loss, label='Val loss', color= "yellow")
ax[0].set_title('Training loss evolution')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].grid(True, alpha = 0.4)
ax[0].legend()

# Zoom últimas épocas
ax[1].plot(epochs[-zoom_epochs:], loss[-zoom_epochs:], label='Train loss', color = "blue")
ax[1].plot(epochs[-zoom_epochs:], val_loss[-zoom_epochs:], label='Val loss', color= "yellow")
ax[1].set_title(f'Zoom últimas {zoom_epochs} epocas')
ax[1].set_xlabel('Epoch')
ax[1].grid(True, alpha = 0.4)
ax[1].legend()

# Visualizacion de accuracy durante el entrenamiento
ax[2].plot( acc, label='Train accuracy', color = "blue")
ax[2].plot( val_acc, label='Val accuracy', color= "yellow")
ax[2].grid(True, alpha = 0.4)
ax[2].set_ylim(0,1)
ax[2].set_title('Training accuracy evolution')
ax[2].set_ylabel('accuracy')
ax[2].legend()

# Zoom últimas épocas
ax[3].plot(epochs[-zoom_epochs:], acc[-zoom_epochs:], label='Train accuracy', color = "blue")
ax[3].plot(epochs[-zoom_epochs:], val_acc[-zoom_epochs:], label='Val accuracy', color= "yellow")
ax[3].set_title(f'Zoom últimas {zoom_epochs} epocas')
ax[3].grid(True, alpha = 0.4)
ax[3].legend()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, f1_score

datasets = {
    "Train": (X_train, y_train),
    "Val": (X_val, y_val),
    "Test": (X_test, y_test)
}

def evaluate(model, X, y):
    #Convertir a enteros
    y_true = np.argmax(y, axis=1)

    y_pred_probs = model.predict(X)
    y_pred = np.argmax(y_pred_probs, axis=1)

    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average="weighted")
    return acc, f1


def crear_df_metricas(model, datasets):
    results = {}
    for split_name, (X, y) in datasets.items():
        acc, f1 = evaluate(model, X, y)
        results[split_name] = [acc, f1]
    
    df = pd.DataFrame(results, index=["Accuracy", "F1"])
    return df

df = crear_df_metricas(model, datasets)
df.round(3)
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step
#           Train    Val   Test
# Accuracy  0.747  0.756  0.741
# F1        0.737  0.747  0.730

# %%
def plot_barra(metrica, titulo, color):

    plt.figure(figsize=(6,4))
    bars = plt.bar(metrica.index, metrica.values, color=color)
    plt.bar_label(bars)
    plt.title(f"{titulo}: Train vs Validation vs Test")
    plt.ylabel(titulo)
    plt.ylim(0,1)
    plt.grid(axis='y', linestyle='--')
    plt.show()


def plots_metricas(df):
    #Extraemos la fila
    accuracy = df.loc["Accuracy"]
    f1 = df.loc["F1"]

    #Grafico de Accuracy
    plot_barra(accuracy, titulo = "Accuracy", color="blue")

    #Grafico de 
    plot_barra(f1, titulo ="F1", color = "red")

# %%
plots_metricas(df)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_true = np.argmax(y_test, axis=1)
y_pred = np.argmax(model.predict(X_test), axis=1)

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm,  
                    display_labels= ["cataract", "diabetic_retinopathy", "glaucoma", "normal"]
                    ).plot(cmap="Blues", xticks_rotation= 45.0)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step

# %%
from sklearn.metrics import precision_recall_fscore_support

def per_class_table(model, datasets):
    # class_names: lista con nombres de las clases en el orden de los índices (opcional)
    class_names = ["cataract", "diabetic_retinopathy", "glaucoma", "normal"]  

    splits = list(datasets.keys())
    # identificamos número de clases desde los datos si no dan nombres
    sample_X, sample_y = next(iter(datasets.values()))
    n_classes = np.argmax(sample_y, axis=1).max() + 1

    # DataFrame con index = clases y columnas por split/metric
    cols = []
    for s in splits:
        cols += [f"{s}_Accuracy", f"{s}_F1"]
    df = pd.DataFrame(index=class_names, columns=cols, dtype=float)

    for split in splits:
        X, y = datasets[split]
        y_true = np.argmax(y, axis=1)
        y_pred = np.argmax(model.predict(X), axis=1)

        # precision, recall, f1 por clase
        precision, recall, f1, support = precision_recall_fscore_support(
            y_true, y_pred, labels=np.arange(n_classes), zero_division=0
        )
        # Aquí definimos "Accuracy" por clase como recall (TP / nº verdaderos de la clase)
        for i, cls in enumerate(class_names):
            df.loc[cls, f"{split}_Accuracy"] = recall[i]
            df.loc[cls, f"{split}_F1"] = f1[i]

    return df

df_per_class = per_class_table(model, datasets)
df_per_class.round(3)
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step
#                       Train_Accuracy  Train_F1  Val_Accuracy  Val_F1  \
# cataract                       0.596     0.614         0.665   0.665
# diabetic_retinopathy           0.997     0.988         0.996   0.983
# glaucoma                       0.481     0.562         0.451   0.522
# normal                         0.891     0.772         0.860   0.776
#
#                       Test_Accuracy  Test_F1
# cataract                      0.567    0.615
# diabetic_retinopathy          0.996    0.982
# glaucoma                      0.468    0.543
# normal                        0.915    0.757

# %%
MODEL_NAME = "modelo_3_simple"          
EPOCHS     = len(hist.epoch)
results = {
    "modelo":         MODEL_NAME,
    "epochs":         EPOCHS,
    "Train Accuracy": df.loc["Accuracy", "Train"],
    "Val Accuracy":   df.loc["Accuracy", "Val"],
    "Test Accuracy":  df.loc["Accuracy", "Test"],
    "Train F1":       df.loc["F1", "Train"],
    "Val F1":         df.loc["F1", "Val"],
    "Test F1":        df.loc["F1", "Test"],

}

# Ruta del CSV
CSV_PATH = "../data/processed/model_results.csv"

if os.path.exists(CSV_PATH):
    df = pd.read_csv(CSV_PATH)
    df = pd.concat([df, pd.DataFrame([results])], ignore_index=True)
else:
    df = pd.DataFrame([results])

df.to_csv(CSV_PATH, index=False)

# %%
df
# Out:
#             modelo  epochs  Train Accuracy  Val Accuracy  Test Accuracy  \
# 0  modelo_4_simple     160        0.879794      0.866114       0.859005
# 1         modelo_3     140        0.469751      0.483412       0.462085
# 2  modelo_2_simple     150        0.567813      0.555687       0.584123
# 3  modelo_3_simple     160        0.762357      0.748815       0.718009
# 4  modelo_5_simple     160        0.741795      0.736967       0.718009
# 5  modelo_2_simple     150        0.736259      0.726303       0.710900
# 6  modelo_3_simple     160        0.746540      0.755924       0.740521
#
#    Train F1    Val F1   Test F1
# 0  0.877048  0.859835  0.854445
# 1  0.467340  0.480129  0.462396
# 2  0.545662  0.539349  0.566327
# 3  0.744839  0.734888  0.698080
# 4  0.725975  0.723727  0.703048
# 5  0.712005  0.699472  0.685075
# 6  0.737455  0.747230  0.730042
