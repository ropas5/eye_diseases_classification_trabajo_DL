# %% [markdown]
# # Modelo VGG 2

# %% [markdown]
# Hacemos fine-tuning con el modelo VGG, añadiendo en la cabeza del modelo unas capas densas. En este caso se reentrenan todo el modelo.
#
# Al final tenemos un mejor resultado que con el modelo de VGG con capas congeladas, por lo que tomamos este modelo como el mas complejo de todos y en los siguientes notebooks iremos restandole complejidad. Reutilizando los pesos que hemos obtenido en este modelo para agilizar el entrenamiento para los otros modelos que partan de esta arquitectura.

# %%
# El siguiente codigo sirve para que el notebook funcione igual en colab o en local
# Si se ejecuta en la nube se cargue el repositorio, de esta forma se pueda acceder 
# a los diferentes archivos que necesite para su ejecución de forma automatica
import sys
import os

try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    repo_path = '/content/eye_diseases_classification_trabajo_DL'
    if not os.path.exists(repo_path):
        # !git clone https://github.com/ropas5/eye_diseases_classification_trabajo_DL.git
        sys.path.append('/content/eye_diseases_classification_trabajo_DL/notebooks')
    # from google.colab import userdata
    # userdata.get('kaggle')
    else:
        print("Repo ya existe, actualizando")
        # %cd /content/eye_diseases_classification_trabajo_DL/notebooks
        # !git pull 
        
    #Cargamos el kaggle.json
    import ipywidgets as widgets
    from IPython.display import display
    
    uploader = widgets.FileUpload(accept='.json')
    display(uploader)
else:
    print("Ejecución en local")
    uploader = None
# Out:
# Ejecución en local

# %% [markdown]
# ### Impotacion y preprocesado de datos

# %%
from importacion_preprocesado import descarga_y_carga_de_datos, preprocesamiento


tamany_img = (128,128) # tamaño reducido para colab, porque si no supera la ram
X, y = descarga_y_carga_de_datos(target_size=tamany_img, uploader=uploader)

X_train, X_val, X_test, y_train, y_val, y_test = preprocesamiento(X, y)
# Out:
# Dataset ya existe, solo se van a cargar las imágenes.
# X shape: (4217, 128, 128, 3) y shape: (4217,)

# %% [markdown]
# ### Modelo

# %%
# Importar el modelo
import sys
sys.path.append('../')

import importlib
import models.complejo_vgg_2
importlib.reload(models.complejo_vgg_2) # recargamos el cache para tener la ultima versión del modelo 
from models.complejo_vgg_2 import create_model

# Crear el modelo
model = create_model(input_shape=(128,128,3), num_classes=4, l_rate=0.01)

# %%
model.summary(expand_nested=True)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 4, 4, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ input_layer (InputLayer)   │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block1_conv1 (Conv2D)      │ (None, 128, 128, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block1_conv2 (Conv2D)      │ (None, 128, 128, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block1_pool (MaxPooling2D) │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block2_conv1 (Conv2D)      │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block2_conv2 (Conv2D)      │ (None, 64, 64, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block2_pool (MaxPooling2D) │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block3_conv1 (Conv2D)      │ (None, 32, 32, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block3_conv2 (Conv2D)      │ (None, 32, 32, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block3_conv3 (Conv2D)      │ (None, 32, 32, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block3_pool (MaxPooling2D) │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block4_conv1 (Conv2D)      │ (None, 16, 16, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block4_conv2 (Conv2D)      │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block4_conv3 (Conv2D)      │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block4_pool (MaxPooling2D) │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block5_conv1 (Conv2D)      │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block5_conv2 (Conv2D)      │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block5_conv3 (Conv2D)      │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ block5_pool (MaxPooling2D) │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,109,700 (57.64 MB)
#  Trainable params: 15,109,700 (57.64 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
hist = model.fit(X_train, y_train, validation_data= (X_val, y_val), epochs= 40)
# Out:
# Epoch 1/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 317s 4s/step - accuracy: 0.2610 - loss: 21415.1914 - val_accuracy: 0.2405 - val_loss: 1.3922
# Epoch 2/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 309s 4s/step - accuracy: 0.2349 - loss: 1.5149 - val_accuracy: 0.2405 - val_loss: 1.3871
# Epoch 3/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 318s 4s/step - accuracy: 0.2440 - loss: 1.4034 - val_accuracy: 0.2547 - val_loss: 1.3860
# Epoch 4/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 304s 4s/step - accuracy: 0.2491 - loss: 1.3904 - val_accuracy: 0.2547 - val_loss: 1.3856
# Epoch 5/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 309s 4s/step - accuracy: 0.2590 - loss: 1.3939 - val_accuracy: 0.2547 - val_loss: 1.3851
# Epoch 6/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 306s 4s/step - accuracy: 0.2432 - loss: 1.4203 - val_accuracy: 0.2310 - val_loss: 1.3861
# Epoch 7/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 311s 4s/step - accuracy: 0.2491 - loss: 1.4039 - val_accuracy: 0.2547 - val_loss: 1.3848
# Epoch 8/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 284s 4s/step - accuracy: 0.2598 - loss: 1.3942 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 9/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 240s 3s/step - accuracy: 0.2515 - loss: 1.3863 - val_accuracy: 0.2547 - val_loss: 1.3857
# Epoch 10/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 206s 3s/step - accuracy: 0.2535 - loss: 1.3877 - val_accuracy: 0.2547 - val_loss: 1.3854
# Epoch 11/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - accuracy: 0.2463 - loss: 1.3869 - val_accuracy: 0.2737 - val_loss: 1.3854
# Epoch 12/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 220s 3s/step - accuracy: 0.2456 - loss: 1.3886 - val_accuracy: 0.2547 - val_loss: 1.3854
# Epoch 13/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 223s 3s/step - accuracy: 0.2511 - loss: 1.3871 - val_accuracy: 0.2547 - val_loss: 1.3857
# Epoch 14/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 201s 3s/step - accuracy: 0.2614 - loss: 1.3871 - val_accuracy: 0.2547 - val_loss: 1.3866
# Epoch 15/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 214s 3s/step - accuracy: 0.2535 - loss: 1.3866 - val_accuracy: 0.2547 - val_loss: 1.3856
# Epoch 16/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 228s 3s/step - accuracy: 0.2610 - loss: 1.3877 - val_accuracy: 0.2737 - val_loss: 1.3850
# Epoch 17/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 204s 3s/step - accuracy: 0.2349 - loss: 1.3872 - val_accuracy: 0.2547 - val_loss: 1.3851
# Epoch 18/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 216s 3s/step - accuracy: 0.2594 - loss: 1.3865 - val_accuracy: 0.2547 - val_loss: 1.3860
# Epoch 19/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 229s 3s/step - accuracy: 0.2459 - loss: 1.3869 - val_accuracy: 0.2737 - val_loss: 1.3853
# Epoch 20/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 236s 3s/step - accuracy: 0.2578 - loss: 1.3882 - val_accuracy: 0.2737 - val_loss: 1.3852
# Epoch 21/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 221s 3s/step - accuracy: 0.2550 - loss: 1.3865 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 22/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 232s 3s/step - accuracy: 0.2610 - loss: 1.3868 - val_accuracy: 0.2547 - val_loss: 1.3858
# Epoch 23/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 330s 4s/step - accuracy: 0.2487 - loss: 1.3857 - val_accuracy: 0.2547 - val_loss: 1.3861
# Epoch 24/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 396s 5s/step - accuracy: 0.2550 - loss: 1.3868 - val_accuracy: 0.2547 - val_loss: 1.3862
# Epoch 25/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 388s 5s/step - accuracy: 0.2610 - loss: 1.3868 - val_accuracy: 0.2547 - val_loss: 1.3853
# Epoch 26/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 387s 5s/step - accuracy: 0.2519 - loss: 1.3884 - val_accuracy: 0.2547 - val_loss: 1.3862
# Epoch 27/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 426s 5s/step - accuracy: 0.2610 - loss: 181.3085 - val_accuracy: 0.2547 - val_loss: 1.3859
# Epoch 28/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 297s 4s/step - accuracy: 0.2499 - loss: 1696.7013 - val_accuracy: 0.2547 - val_loss: 1.3861
# Epoch 29/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 190s 2s/step - accuracy: 0.2432 - loss: 6285095.0000 - val_accuracy: 0.2737 - val_loss: 1.3848
# Epoch 30/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 189s 2s/step - accuracy: 0.2539 - loss: 1907132.6250 - val_accuracy: 0.2737 - val_loss: 1.3852
# Epoch 31/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 196s 2s/step - accuracy: 0.2578 - loss: 1.3863 - val_accuracy: 0.2547 - val_loss: 1.3851
# Epoch 32/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 192s 2s/step - accuracy: 0.2550 - loss: 61711.9180 - val_accuracy: 0.2547 - val_loss: 1.3851
# Epoch 33/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 188s 2s/step - accuracy: 0.2519 - loss: 1.4016 - val_accuracy: 0.2547 - val_loss: 1.3855
# Epoch 34/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 188s 2s/step - accuracy: 0.2503 - loss: 1.4071 - val_accuracy: 0.2547 - val_loss: 1.3867
# Epoch 35/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 187s 2s/step - accuracy: 0.2610 - loss: 1.3960 - val_accuracy: 0.2547 - val_loss: 1.3854
# Epoch 36/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 187s 2s/step - accuracy: 0.2546 - loss: 1.3867 - val_accuracy: 0.2737 - val_loss: 1.3858
# Epoch 37/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 188s 2s/step - accuracy: 0.2495 - loss: 1.3867 - val_accuracy: 0.2547 - val_loss: 1.3862
# Epoch 38/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 187s 2s/step - accuracy: 0.2459 - loss: 1.3871 - val_accuracy: 0.2547 - val_loss: 1.3861
# Epoch 39/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 190s 2s/step - accuracy: 0.2503 - loss: 1.4007 - val_accuracy: 0.2547 - val_loss: 1.3850
# Epoch 40/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 188s 2s/step - accuracy: 0.2610 - loss: 1.3867 - val_accuracy: 0.2547 - val_loss: 1.3860

# %% [markdown]
# Guardamos los pesos de este modelo para inicializar los siguientes modelos, que parten desde este modelo.

# %%
import torch
import torchvision.models as models

model.save_weights('../models/vgg_pesos.weights.h5') # guardar solo los pesos

# %% [markdown]
# ### Resultados

# %%
import matplotlib.pyplot as plt
import numpy as np

# número de épocas para el zoom
zoom_epochs = 20

loss = hist.history['loss']
val_loss = hist.history['val_loss']
acc = hist.history["accuracy"]
val_acc = hist.history["val_accuracy"]

epochs = range(1, len(loss) + 1)

fig, ax = plt.subplots(2, 2, figsize=(13,10))
ax  = ax.flatten()
fig.suptitle('Training History', fontsize=15, fontweight='bold')

# Visualizacion evolucion loss durante el entrenamiento
ax[0].plot( loss, label='Train loss', color = "blue")
ax[0].plot( val_loss, label='Val loss', color= "yellow")
ax[0].set_title('Training loss evolution')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].grid(True, alpha = 0.4)
ax[0].legend()

# Zoom últimas épocas
ax[1].plot(epochs[-zoom_epochs:], loss[-zoom_epochs:], label='Train loss', color = "blue")
ax[1].plot(epochs[-zoom_epochs:], val_loss[-zoom_epochs:], label='Val loss', color= "yellow")
ax[1].set_title(f'Zoom últimas {zoom_epochs} epocas')
ax[1].set_xlabel('Epoch')
ax[1].grid(True, alpha = 0.4)
ax[1].legend()

# Visualizacion de accuracy durante el entrenamiento
ax[2].plot( acc, label='Train accuracy', color = "blue")
ax[2].plot( val_acc, label='Val accuracy', color= "yellow")
ax[2].grid(True, alpha = 0.4)
ax[2].set_ylim(0,1)
ax[2].set_title('Training accuracy evolution')
ax[2].set_ylabel('accuracy')
ax[2].legend()

# Zoom últimas épocas
ax[3].plot(epochs[-zoom_epochs:], acc[-zoom_epochs:], label='Train accuracy', color = "blue")
ax[3].plot(epochs[-zoom_epochs:], val_acc[-zoom_epochs:], label='Val accuracy', color= "yellow")
ax[3].set_title(f'Zoom últimas {zoom_epochs} epocas')
ax[3].grid(True, alpha = 0.4)
ax[3].legend()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, f1_score

datasets = {
    "Train": (X_train, y_train),
    "Val": (X_val, y_val),
    "Test": (X_test, y_test)
}

def evaluate(model, X, y):
    #Convertir a enteros
    y_true = np.argmax(y, axis=1)

    y_pred_probs = model.predict(X)
    y_pred = np.argmax(y_pred_probs, axis=1)

    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average="weighted")
    return acc, f1


def crear_df_metricas(model, datasets):
    results = {}
    for split_name, (X, y) in datasets.items():
        acc, f1 = evaluate(model, X, y)
        results[split_name] = [acc, f1]
    
    df = pd.DataFrame(results, index=["Accuracy", "F1"])
    return df

# %%
df = crear_df_metricas(model, datasets)
print(df.round(3))
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 45s 555ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 521ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 15s 531ms/step
#           Train    Val   Test
# Accuracy  0.261  0.255  0.236
# F1        0.108  0.103  0.090

# %%
def plot_barra(metrica, titulo, color):

    plt.figure(figsize=(6,4))
    bars = plt.bar(metrica.index, metrica.values, color=color)
    plt.bar_label(bars)
    plt.title(f"{titulo}: Train vs Validation vs Test")
    plt.ylabel(titulo)
    plt.ylim(0,1)
    plt.grid(axis='y', linestyle='--')
    plt.show()


def plots_metricas(df):
    #Extraemos la fila
    accuracy = df.loc["Accuracy"]
    f1 = df.loc["F1"]

    #Grafico de Accuracy
    plot_barra(accuracy, titulo = "Accuracy", color="blue")

    #Grafico de 
    plot_barra(f1, titulo ="F1", color = "red")

# %%
plots_metricas(df)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_true = np.argmax(y_test, axis=1)
y_pred = np.argmax(model.predict(X_test), axis=1)

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm,  
                    display_labels= ["cataract", "diabetic_retinopathy", "glaucoma", "normal"]
                    ).plot(cmap="Blues", xticks_rotation= 45.0)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 16s 569ms/step

# %%
from sklearn.metrics import precision_recall_fscore_support

def per_class_table(model, datasets):
    # class_names: lista con nombres de las clases en el orden de los índices (opcional)
    class_names = ["cataract", "diabetic_retinopathy", "glaucoma", "normal"]  

    splits = list(datasets.keys())
    # identificamos número de clases desde los datos si no dan nombres
    sample_X, sample_y = next(iter(datasets.values()))
    n_classes = np.argmax(sample_y, axis=1).max() + 1

    # DataFrame con index = clases y columnas por split/metric
    cols = []
    for s in splits:
        cols += [f"{s}_Accuracy", f"{s}_F1"]
    df = pd.DataFrame(index=class_names, columns=cols, dtype=float)

    for split in splits:
        X, y = datasets[split]
        y_true = np.argmax(y, axis=1)
        y_pred = np.argmax(model.predict(X), axis=1)

        # precision, recall, f1 por clase
        precision, recall, f1, support = precision_recall_fscore_support(
            y_true, y_pred, labels=np.arange(n_classes), zero_division=0
        )
        # Aquí definimos "Accuracy" por clase como recall (TP / nº verdaderos de la clase)
        for i, cls in enumerate(class_names):
            df.loc[cls, f"{split}_Accuracy"] = recall[i]
            df.loc[cls, f"{split}_F1"] = f1[i]

    return df

# %%
df_per_class = per_class_table(model, datasets)
print(df_per_class.round(3))
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 49s 611ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 15s 565ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 16s 580ms/step
#                       Train_Accuracy  Train_F1  Val_Accuracy  Val_F1  \
# cataract                         0.0     0.000           0.0   0.000
# diabetic_retinopathy             0.0     0.000           0.0   0.000
# glaucoma                         0.0     0.000           0.0   0.000
# normal                           1.0     0.414           1.0   0.406
#
#                       Test_Accuracy  Test_F1
# cataract                        0.0    0.000
# diabetic_retinopathy            0.0    0.000
# glaucoma                        0.0    0.000
# normal                          1.0    0.382

# %%
MODEL_NAME = "modelo_vgg_2"          
EPOCHS     = len(hist.epoch)
results = {
    "modelo":         MODEL_NAME,
    "epochs":         EPOCHS,
    "Train Accuracy": df.loc["Accuracy", "Train"],
    "Val Accuracy":   df.loc["Accuracy", "Val"],
    "Test Accuracy":  df.loc["Accuracy", "Test"],
    "Train F1":       df.loc["F1", "Train"],
    "Val F1":         df.loc["F1", "Val"],
    "Test F1":        df.loc["F1", "Test"],

}

# Ruta del CSV
CSV_PATH = "../data/processed/model_results.csv"

if os.path.exists(CSV_PATH):
    df = pd.read_csv(CSV_PATH)
    df = pd.concat([df, pd.DataFrame([results])], ignore_index=True)
else:
    df = pd.DataFrame([results])

df.to_csv(CSV_PATH, index=False)

# %%
df
# Out:
#              modelo  epochs  Train Accuracy  Val Accuracy  Test Accuracy  \
# 0          modelo_3     140        0.469751      0.483412       0.462085
# 1   modelo_2_simple     200        0.811388      0.806872       0.795024
# 2   modelo_3_simple     160        0.762357      0.748815       0.718009
# 3   modelo_4_simple     160        0.879794      0.866114       0.859005
# 4   modelo_5_simple     160        0.741795      0.736967       0.718009
# 5   modelo_6_simple     100        0.811000      0.815000       0.808000
# 6        modelo_vgg      70        0.866000      0.850000       0.853000
# 7      modelo_vgg_2      40        0.260973      0.254739       0.235782
# 8      modelo_vgg_3      40        0.999209      0.906980       0.913507
# 9      modelo_vgg_4      40        0.997628      0.914692       0.926540
# 10     modelo_vgg_5      40        0.260973      0.254739       0.235782
# 11     modelo_vgg_2      40        0.260973      0.254739       0.235782
#
#     Train F1    Val F1   Test F1
# 0   0.467340  0.480129  0.462396
# 1   0.801620  0.792162  0.784455
# 2   0.744839  0.734888  0.698080
# 3   0.877048  0.859835  0.854445
# 4   0.725975  0.723727  0.703048
# 5   0.793000  0.798000  0.789000
# 6   0.865000  0.847000  0.850000
# 7   0.108023  0.103435  0.089972
# 8   0.999209  0.906495  0.913191
# 9   0.997628  0.914033  0.925701
# 10  0.108023  0.103435  0.089972
# 11  0.108023  0.103435  0.089972
